# %%
import pandas as pd 

df = pd.read_csv('assessment.csv')


df = df[df['Price'].notna()]


df['Category'] = df['Category'].replace(r'[^A-Za-z0-9_]', '', regex=True)


df= df.groupby(['Category', 'Material'])['Price'].mean().reset_index().round(2)


df = df.rename(columns={'Price': 'AveragePrice'})


print(df)
# Out:
#         Category Material  AveragePrice
# 0          Books   Fabric        150.84
# 1          Books    Glass        118.53
# 2          Books  Leather        972.42
# 3          Books  Plastic        139.00
# 4          Books     Wood        802.11
# 5       Clothing  Leather        610.49
# 6       Clothing    Metal        630.28
# 7       Clothing  Plastic        470.66
# 8       Clothing     Wood        365.26
# 9    Electronics   Fabric        654.30
# 10   Electronics     Wood        136.37
# 11  HealthBeauty    Metal        667.63
# 12   HomeKitchen   Fabric        340.24
# 13   HomeKitchen     Wood        177.76
# 14        Sports   Fabric        567.32
# 15        Sports    Glass        936.66
# 16        Sports     Wood        961.88
# 17     ToysGames   Fabric        385.06
# 18     ToysGames  Leather        500.34
# 19     ToysGames    Metal        364.83

# %%
import pandas as pd 

df = pd.read_csv('assessment.csv')

df['lowquality'] = df['Rating (out of 5)'].apply(lambda x: 'True' if x < 2 else 'False')

df
# Out:
#    Product ID Product Name         Category   Price  Discount (%)  \
# 0       P0001        RXEFO            Books  118.53             8
# 1       P0002        GHERI   Home & Kitchen  340.24            19
# 2       P0003        VDIQP     Toys & Games  538.28            36
# 3       P0004        MDXQE     Toys & Games  191.38            47
# 4       P0005        EVMHN     Toys & Games  385.06            46
# 5       P0006        KTQVF            Books  802.11             6
# 6       P0007        FHTQN            Books  139.00            33
# 7       P0008        RXGQI         Clothing  610.49            13
# 8       P0009        NPDKU         Clothing  902.73            31
# 9       P0010        OHEJY           Sports  567.32            21
# 10      P0011        XEFZV  Health & Beauty  667.63            44
# 11      P0012        ONABK            Books  150.84            41
# 12      P0013        SRUPI      Electronics  654.30            23
# ...

# %%
import pandas as pd 

df = pd.read_csv('assessment.csv')
df['lowquality'] = df['Rating (out of 5)'].apply(lambda x: 'True' if x < 2 else 'False')

avg_prices = df.groupby('lowquality')['Price'].mean().reset_index().round(2)
avg_prices = avg_prices.rename(columns={'Price': 'AveragePrice'})
total_avg_price = df['Price'].mean().round(2)


print(avg_prices)
print("Total average price:", total_avg_price)
# Out:
#   lowquality  AveragePrice
# 0      False        502.35
# 1       True        620.00
# Total average price: 517.06

# %%
# Calculate and display the average price for lowquality and non-lowquality products#

# %%
# Display which category has the most lowquality rows
lowquality_counts = df[df['Rating (out of 5)'] <= 2].groupby('Category').size().reset_index(name='lowquality_count')
most_lowquality_category = lowquality_counts.sort_values('lowquality_count', ascending=False).head(1)
print(most_lowquality_category)
# Out:
#        Category  lowquality_count
# 2  Toys & Games                 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the data
df = pd.read_csv('assessment.csv')

# Calculate average price by category
category_sales = df.groupby('Category')['Price'].mean().reset_index()

# Create the plot
plt.figure(figsize=(12, 6))
sns.barplot(data=category_sales, x='Category', y='Price')

# Customize the plot
plt.title('Average Price by Category')
plt.xlabel('Category')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 import seaborn as sns
#       5 # Read the data
#       6 df = pd.read_csv('assessment.csv')
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('assessment.csv')

# Calculate average price by category
category_sales = df.groupby('Category')['Price'].mean().reset_index()

# Create the plot
plt.figure(figsize=(12, 6))
plt.bar(category_sales['Category'], category_sales['Price'])

# Customize the plot
plt.title('Average Price by Category')
plt.xlabel('Category')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data
df = pd.read_csv('assessment.csv')

# Calculate average price by category
category_sales = df.groupby('Category')['Price'].mean().reset_index()

# Create the plot
plt.figure(figsize=(12, 6))
plt.bar(category_sales['Category'], category_sales['Price'])

# Customize the plot
plt.title('Average Price by Category')
plt.xlabel('Category')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
